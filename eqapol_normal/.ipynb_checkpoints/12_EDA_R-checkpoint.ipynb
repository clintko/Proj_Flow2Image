# %%
library(tidyverse)
library(gridExtra)
# Out:
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
DAT_DIR = "/data/flow/EQAPOL_normal"
RES_DIR = "/data/clinko/"
FIG_DIR = "/local_data/notebooks/clintko/GitRepo/Proj_Flow2Image/fig"

# %% [markdown]
# ```
# /data/flow/EQAPOL_normal/AMJ_5L_CMV_pp65.txt
# /data/flow/EQAPOL_normal/AMJ_5L_Costim.txt
# /data/flow/EQAPOL_normal/AMJ_5L_SEB.txt
# ```

# %%
system("cat /data/flow/EQAPOL_normal/markers.txt", intern = TRUE)
# Out:
#  [1] "Scatter,FSC-H"           "Scatter,FSC-W"
#  [3] "Scatter,FSC-A"           "Basic,CD14 CD19 vAmine"
#  [5] "Basic,CD3 AmCyan"        "Basic,CD4 PerCP Cy55"
#  [7] "Basic,CD8 APC Cy7"       "Maturational,CD45RO ECD"
#  [9] "Maturational,CD27 APC"   "Maturational,CD57 FITC"
# [11] "Functional,TNFa A700"    "Functional,IL 2 PE"
# [13] "Functional,IFNg PE Cy7"  "Functional,CD107 PE Cy5"

# %%
system("head -2 /data/flow/EQAPOL_normal/AMJ_5L_Costim.txt", intern = TRUE)
# Out:
# [1] "1.018520000000000000e+05 7.418068750000000000e+04 1.152870390625000000e+05 1.759094539995357263e+04 5.491982804719817068e+04 5.510407547093065659e+04 8.990052291904521553e+03 3.278475823798456986e+04 4.536509548637057742e+04 2.876466786316298021e+04 2.580220143132071098e+04 1.742527342681746813e+04 2.488605874349489022e+04 4.232201490729571378e+04"
# [2] "4.746600000000000000e+04 1.137904843750000000e+05 8.241544531250000000e+04 3.779531456800597516e+04 4.694085147949823295e+04 4.298605160111440455e+03 3.073039705648520248e+04 6.054493787331152998e+04 4.071986162027496448e+03 8.641595290316012324e+03 2.040992783462718580e+04 3.288313297334415256e+04 3.450551827655782108e+04 5.211524941057188698e+04"

# %%
fpath = file.path(DAT_DIR, "markers.txt")
marker = read_csv(fpath, col_names = FALSE)

fpath = file.path(DAT_DIR, "B6901GFJ-08_Costim.txt")
dat_costim = read_delim(fpath, col_names = FALSE, delim = " ")
colnames(dat_costim) = marker$X2

fpath = file.path(DAT_DIR, "B6901GFJ-08_CMV_pp65.txt")
dat_cmv = read_delim(fpath, col_names = FALSE, delim = " ")
colnames(dat_cmv) = marker$X2

fpath = file.path(DAT_DIR, "B6901GFJ-08_SEB.txt")
dat_seb = read_delim(fpath, col_names = FALSE, delim = " ")
colnames(dat_seb) = marker$X2
# Out:
# Parsed with column specification:
# cols(
#   X1 = col_character(),
#   X2 = col_character()
# )
# Parsed with column specification:
# cols(
#   X1 = col_double(),
#   X2 = col_double(),
#   X3 = col_double(),
#   X4 = col_double(),
#   X5 = col_double(),
#   X6 = col_double(),
#   X7 = col_double(),
#   X8 = col_double(),
#   X9 = col_double(),
#   X10 = col_double(),
#   X11 = col_double(),
#   X12 = col_double(),
#   X13 = col_double(),
#   X14 = col_double()
# )
# Parsed with column specification:
# cols(
#   X1 = col_double(),
#   X2 = col_double(),
#   X3 = col_double(),
#   X4 = col_double(),
#   X5 = col_double(),
#   X6 = col_double(),
#   X7 = col_double(),
#   X8 = col_double(),
#   X9 = col_double(),
#   X10 = col_double(),
#   X11 = col_double(),
#   X12 = col_double(),
#   X13 = col_double(),
#   X14 = col_double()
# )
# Parsed with column specification:
# cols(
#   X1 = col_double(),
#   X2 = col_double(),
#   X3 = col_double(),
#   X4 = col_double(),
# ...

# %%
head(dat_costim)
# Out:
#   FSC-H  FSC-W    FSC-A     CD14 CD19 vAmine CD3 AmCyan CD4 PerCP Cy55
# 1  85260 89632.81 116609.09 38387.607        50245.73   40094.351
# 2  83880 76323.14  97686.52 17854.954        18938.01   13645.215
# 3  77985 76107.66  90564.80 41827.465        36393.83   41013.530
# 4  66203 75817.44  76589.08 14368.130        55787.10   54091.083
# 5 178254 93635.41 254682.69 21989.705        62916.87    2420.449
# 6  86640 77111.73 101943.36  9917.962        53049.51   -4665.076
#   CD8 APC Cy7 CD45RO ECD CD27 APC  CD57 FITC TNFa A700 IL 2 PE  IFNg PE Cy7
# 1 -7404.433   56457.187  23234.708 18888.052 51672.200 41595.47 32151.79
# 2 16683.337    1579.537   6597.411 15157.431 20288.298 21395.18 22696.28
# 3 47924.791   61757.223  18124.235 16972.745 67436.187 25973.66 22449.24
# 4 28586.175    3188.824  45055.597 29874.413 30414.034 16565.56 23177.01
# 5 72381.855   55605.566  52942.233 34336.541 37081.736 17086.72 29143.67
# ...

# %%
script_combine = function(idx){
    ###
    idx1 = idx[1]; idx2 = idx[2]
    df1 = dat_costim[, c(idx1, idx2)]
    df2 = dat_cmv[,    c(idx1, idx2)]
    df3 = dat_seb[,    c(idx1, idx2)]
    df  = bind_rows(df1, df2, df3)
    
    ###
    trt = c(rep("costim", nrow(df1)), 
            rep("CMV",    nrow(df2)), 
            rep("SEB",    nrow(df3)))
    df$treatment = factor(trt, levels = c("costim", "CMV", "SEB"))
    return(df)
}

# %%
script_get_idx = function(query){
    mk  = marker$X2
    idx = sapply(query, grep, x = mk, ignore.case = TRUE)
    val = sapply(query, grep, x = mk, ignore.case = TRUE, value = TRUE)
    names(idx) = val
    return(idx)
}

# %%
print(script_get_idx(c("cd4 ", "cd4 ")))
print(script_get_idx(c("cd4 ", "ifn")))
print(script_get_idx(c("CD3" , "CD45RO")))
# Out:
# CD4 PerCP Cy55 CD4 PerCP Cy55
#              6              6
# CD4 PerCP Cy55    IFNg PE Cy7
#              6             13
# CD3 AmCyan CD45RO ECD
#          5          8

# %%
idx = script_get_idx(c("CD4 ", "ifn"))
dat = script_combine(idx)
dat_ifng_cd4 = dat

idx = script_get_idx(c("CD8 ", "ifn"))
dat = script_combine(idx)
dat_ifng_cd8 = dat

idx = script_get_idx(c("CD3" , "CD45RO"))
dat = script_combine(idx)
dat_cd45_cd3 = dat

# %%
library(IRdisplay)

# %%
display(head(dat_ifng_cd4, 2))
display(head(dat_ifng_cd8, 2))
display(head(dat_cd45_cd3, 2))
# Out:
#   CD4 PerCP Cy55 IFNg PE Cy7 treatment
# 1 40094.35       32151.79    costim
# 2 13645.21       22696.28    costim
#   CD8 APC Cy7 IFNg PE Cy7 treatment
# 1 -7404.433   32151.79    costim
# 2 16683.337   22696.28    costim
#   CD3 AmCyan CD45RO ECD treatment
# 1 50245.73   56457.187  costim
# 2 18938.01    1579.537  costim

# %%
options(repr.plot.height = 4, repr.plot.width = 12)

###
set.seed(123)
df  = dat_ifng_cd4
df  = df %>% dplyr::sample_frac(0.5)
lab = colnames(df)[1:2]
lab = stringr::str_split(lab, " ")
lab = lapply(lab, `[[`, 1) %>% unlist

###
colnames(df)[1:2] = c("x", "y")
gp = df %>% 
    ggplot(aes(x = x, y = y, group = treatment)) + 
    geom_hex(bins = 200) +
    geom_rect(xmin=40000, xmax=80000, ymin=50000, ymax=90000, 
              color = "red", size = 1.5, alpha = 0) +
    labs(x = lab[1], y = lab[2]) +
    facet_wrap(~treatment) +
    theme_light() +
    theme(strip.text.x = element_text(size = 20))

gp1 = gp    
print(gp)
# Out:
# plot without title

# %%
options(repr.plot.height = 4, repr.plot.width = 12)

###
df  = dat_ifng_cd8
df  = df %>% dplyr::sample_frac(0.5)
lab = colnames(df)[1:2]
lab = stringr::str_split(lab, " ")
lab = lapply(lab, `[[`, 1) %>% unlist

###
colnames(df)[1:2] = c("x", "y")
gp = df %>% 
    ggplot(aes(x = x, y = y, group = treatment)) + 
    geom_hex(bins = 200) +
    geom_rect(xmin=30000, xmax=70000, ymin=50000, ymax=90000, 
              color = "red", size = 1.5, alpha = 0) +
    labs(x = lab[1], y = lab[2]) +
    facet_wrap(~treatment) +
    theme_light() +
    theme(strip.text.x = element_text(size = 20))

gp2 = gp
print(gp)
# Out:
# plot without title

# %%
options(repr.plot.height = 8, repr.plot.width = 12)
gp = arrangeGrob(gp1, gp2, ncol=1)
print(gp)
# Out:
# TableGrob (2 x 1) "arrange": 2 grobs
#   z     cells    name           grob
# 1 1 (1-1,1-1) arrange gtable[layout]
# 2 2 (2-2,1-1) arrange gtable[layout]

# %%
ggsave(file=file.path(FIG_DIR, "eqapol_norm_ifng.png"), gp, dpi = 300, width = 30, height = 20, unit = "cm")

# %%
### Basic
import numpy  as np
import scipy  as sc
import pandas as pd
import glob, os, re
import pickle, sys

### import flowImg
py_path = "/local_data/notebooks/clintko/GitRepo/Proj_Flow2Image"
sys.path.insert(0, py_path)
from flowImg import *

### directory
DAT_DIR = "/data/clintko/flow_EQAPOL_normal"

# %%
# !ls /data/clintko
# Out:
# case_studies_mod01  environment		samtools-1.8	      test
# data_pbmc	    flow_EQAPOL		samtools-1.8.tar.bz2  Trimmomatic
# DropSeq_Lung	    flow_EQAPOL_normal	SMPK
# DukeHTS2018	    flow_simulated	STAR
